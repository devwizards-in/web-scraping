# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import logging

# %%
flipcart_url = "https://www.flipkart.com/search?q=" + "iphone11"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone11'

# %%
urlclient = uReq(flipcart_url)

# %%
urlclient

# %%
flipcart_page = urlclient.read()

# %%
flipcart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
flipcarthtml = bs(flipcart_page,'html.parser')

# %%
flipcarthtml
# Out:
# <!DOCTYPE html>
# ...

# %%
"https://www.flipkart.com/"+"apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&li…EARCH&ppt=sp&ppn=sp&ssid=9ksm58186o0000001685666119577&qH=d6db477051465f9a"
# Out:
# 'https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&li…EARCH&ppt=sp&ppn=sp&ssid=9ksm58186o0000001685666119577&qH=d6db477051465f9a'

# %%
bigbox = flipcarthtml.findAll("div" , {"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 30

# %%
bigbox[3].div.div.div.a['href']
# Out:
# '/apple-iphone-11-black-128-gb/p/itm8244e8d955aba?pid=MOBFWQ6BKRYBP5X8&lid=LSTMOBFWQ6BKRYBP5X8IBG6BS&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=58393bce-3f4f-4ce6-bed6-ad41a0c54732.MOBFWQ6BKRYBP5X8.SEARCH&ppt=None&ppn=None&ssid=icqkd2t2eo0000001685685339344&qH=d6db477051465f9a'

# %%
product_link = "https://www.flipkart.com" +  bigbox[3].div.div.div.a['href']

# %%
del bigbox[0:3]

# %%
for i in bigbox:
    print("https://www.flipkart.com" +  bigbox[3].div.div.div.a['href'])
# Out:
# https://www.flipkart.com/apple-iphone-11-purple-64-gb/p/itm2b8d03427ddac?pid=MOBFWQ6BTFFJKGKE&lid=LSTMOBFWQ6BTFFJKGKEPGQVOJ&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=58393bce-3f4f-4ce6-bed6-ad41a0c54732.MOBFWQ6BTFFJKGKE.SEARCH&ppt=None&ppn=None&ssid=icqkd2t2eo0000001685685339344&qH=d6db477051465f9a
# https://www.flipkart.com/apple-iphone-11-purple-64-gb/p/itm2b8d03427ddac?pid=MOBFWQ6BTFFJKGKE&lid=LSTMOBFWQ6BTFFJKGKEPGQVOJ&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=58393bce-3f4f-4ce6-bed6-ad41a0c54732.MOBFWQ6BTFFJKGKE.SEARCH&ppt=None&ppn=None&ssid=icqkd2t2eo0000001685685339344&qH=d6db477051465f9a
# ...

# %%
for i in bigbox:
    print("https://www.flipkart.com" +  i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/apple-iphone-11-black-128-gb/p/itm8244e8d955aba?pid=MOBFWQ6BKRYBP5X8&lid=LSTMOBFWQ6BKRYBP5X8IBG6BS&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=58393bce-3f4f-4ce6-bed6-ad41a0c54732.MOBFWQ6BKRYBP5X8.SEARCH&ppt=None&ppn=None&ssid=icqkd2t2eo0000001685685339344&qH=d6db477051465f9a
# https://www.flipkart.com/apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=58393bce-3f4f-4ce6-bed6-ad41a0c54732.MOBFWQ6BVWVEH3XE.SEARCH&ppt=None&ppn=None&ssid=icqkd2t2eo0000001685685339344&qH=d6db477051465f9a
# ...

# %%
product_link
# Out:
# 'https://www.flipkart.com/apple-iphone-11-purple-64-gb/p/itm2b8d03427ddac?pid=MOBFWQ6BTFFJKGKE&lid=LSTMOBFWQ6BTFFJKGKEPGQVOJ&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=58393bce-3f4f-4ce6-bed6-ad41a0c54732.MOBFWQ6BTFFJKGKE.SEARCH&ppt=None&ppn=None&ssid=icqkd2t2eo0000001685685339344&qH=d6db477051465f9a'

# %%
#phone details page 2nd page

# %%
product_req = requests.get(product_link)

# %%
product_html = bs(product_req.text,"html.parser")

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
comment_box = product_html.findAll("div",{"class" : "_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[0].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Flipkart Customer'

# %%
#get names 
for i in comment_box:
    print(i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Flipkart Customer
# Flipkart Customer
# Manish Raghuvanshi
# Jimly  Gogoi
# George Haokip
# Vamshi  Chakrala
# vijay hegde
# Chirag Rajput
# Vishal Dubey
# Rahul Verma
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [90], line 3
#       1 #get names
#       2 for i in comment_box:
# ----> 3     print(i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
#rating for one
comment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
#all rating
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 5
# 4
# 5
# 4
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [96], line 3
#       1 #all rating
#       2 for i in comment_box:
# ----> 3     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
#find one comment 
comment_box[0].div.div.div.find('p',{"class" : "_2-N8zT"}).text
# Out:
# 'Simply awesome'

# %%
#find all comments

# %%
for i in comment_box:
    print(i.div.div.div.find('p',{"class" : "_2-N8zT"}).text)
# Out:
# Simply awesome
# Perfect product!
# Best in the market!
# Highly recommended
# Value-for-money
# Worth every penny
# Pretty good
# Perfect product!
# Highly recommended
# Great product
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [105], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.find('p',{"class" : "_2-N8zT"}).text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
#find actual comment

comment_box[0].div.div.find_all("div",{"class" : ""})[0].div.text
# Out:
# 'Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.'

# %%
#find all actual comment

for i in comment_box:
    print(i.div.div.find_all("div",{"class":""})[0].div.text)
# Out:
# Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.
# Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .
# Great iPhone very snappy experience as apple kind. Upgraded from iPhone 7. Pros-Camera top class - Battery top performed -Chipset no need to say as apple kind -Security as you expect from apple - Display super bright industry leading colour   accuracy and super responsive -Build quality as expect from apple sturdy  premium durable beautiful stylish. -Os most stable os in smartphone industry Cons -No 5G-Display is not based on OLED technology -Charger headphones and 1 apple stic...
# ...
